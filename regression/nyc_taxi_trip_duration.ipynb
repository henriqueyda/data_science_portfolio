# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.765602                  N            455
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458644 entries, 0 to 1458643
# Data columns (total 11 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id                  1458644 non-null  object
#  1   vendor_id           1458644 non-null  int64
#  2   pickup_datetime     1458644 non-null  object
#  3   dropoff_datetime    1458644 non-null  object
#  4   passenger_count     1458644 non-null  int64
#  5   pickup_longitude    1458644 non-null  float64
#  6   pickup_latitude     1458644 non-null  float64
#  7   dropoff_longitude   1458644 non-null  float64
#  8   dropoff_latitude    1458644 non-null  float64
#  9   store_and_fwd_flag  1458644 non-null  object
#  10  trip_duration       1458644 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 122.4+ MB

# %%
df_train['pickup_datetime'] = pd.to_datetime(df_train['pickup_datetime'])
df_train['dropoff_datetime'] = pd.to_datetime(df_train['dropoff_datetime'])

# %%
df_train
# Out:
#                 id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0        id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1        id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2        id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3        id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4        id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
# ...            ...        ...                 ...                 ...
# 1458639  id2376096          2 2016-04-08 13:31:04 2016-04-08 13:44:02
# 1458640  id1049543          1 2016-01-10 07:35:15 2016-01-10 07:46:10
# 1458641  id2304944          2 2016-04-22 06:57:41 2016-04-22 07:10:25
# 1458642  id2714485          1 2016-01-05 15:56:26 2016-01-05 16:02:39
# 1458643  id1209952          1 2016-04-05 14:44:25 2016-04-05 14:47:43
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 0                      1        -73.982155        40.767937
# ...

# %%
df_train['pickup_year'] = df_train['pickup_datetime'].dt.year
df_train['pickup_month'] = df_train['pickup_datetime'].dt.month
df_train['pickup_weekday'] = df_train['pickup_datetime'].dt.weekday
df_train['pickup_time'] = df_train['pickup_datetime'].dt.time

df_train['dropoff_year'] = df_train['dropoff_datetime'].dt.year
df_train['dropoff_month'] = df_train['dropoff_datetime'].dt.month
df_train['dropoff_weekday'] = df_train['dropoff_datetime'].dt.weekday
df_train['dropoff_time'] = df_train['dropoff_datetime'].dt.time

# %%
df_train
# Out:
#                 id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0        id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1        id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2        id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3        id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4        id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
# ...            ...        ...                 ...                 ...
# 1458639  id2376096          2 2016-04-08 13:31:04 2016-04-08 13:44:02
# 1458640  id1049543          1 2016-01-10 07:35:15 2016-01-10 07:46:10
# 1458641  id2304944          2 2016-04-22 06:57:41 2016-04-22 07:10:25
# 1458642  id2714485          1 2016-01-05 15:56:26 2016-01-05 16:02:39
# 1458643  id1209952          1 2016-04-05 14:44:25 2016-04-05 14:47:43
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 0                      1        -73.982155        40.767937
# ...

# %%
df_train['vendor_id'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
df_train['trip_duration'].mean()
# Out:
# 959.4922729603659

# %%
df_train.iloc[1422846]
# Out:
# id                              id0779399
# vendor_id                               2
# pickup_datetime       2016-04-03 15:00:50
# dropoff_datetime      2016-04-04 14:52:25
# passenger_count                         1
# pickup_longitude                 -73.9512
# pickup_latitude                   40.7718
# dropoff_longitude                -73.8631
# dropoff_latitude                  40.7686
# store_and_fwd_flag                      N
# trip_duration                       85895
# pickup_year                          2016
# pickup_month                            4
# pickup_weekday                          6
# pickup_time                      15:00:50
# dropoff_year                         2016
# dropoff_month                           4
# dropoff_weekday                         0
# dropoff_time                     14:52:25
# Name: 1422846, dtype: object

# %%
df_train[df_train['trip_duration'] > 50000]['trip_duration'].min()
# Out:
# 51609

# %%
df_train['trip_duration'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.histplot(df_train['trip_duration'], log_scale = True, bins = 100, color='g')
plt.grid(True, which='both')
plt.show()

# %%
df_train = df_train[(df_train.pickup_latitude > 40.63) & (df_train.pickup_latitude < 40.85)]
df_train = df_train[(df_train.dropoff_latitude > 40.63) & (df_train.dropoff_latitude < 40.85)]
df_train = df_train[(df_train.pickup_longitude > -74.03) & (df_train.pickup_longitude < -73.77)]
df_train = df_train[(df_train.dropoff_longitude > -74.03) & (df_train.dropoff_longitude < -73.77)]

# %%
f, axes = plt.subplots(1,2,figsize=(10, 5), sharex=False, sharey = False)
sns.histplot(df_train['pickup_latitude'],color="r",bins = 50, ax=axes[0])
sns.histplot(df_train['pickup_longitude'],color="r",bins = 50, ax=axes[1])
plt.show()

# %%
f, axes = plt.subplots(1,2,figsize=(10, 5), sharex=False, sharey = False)
sns.histplot(df_train['dropoff_latitude'],color="r",bins = 50, ax=axes[0])
sns.histplot(df_train['dropoff_longitude'],color="r",bins = 50, ax=axes[1])
plt.show()

# %%
plt.figure(figsize = (10,10))
plt.plot(df_train['pickup_longitude'], df_train['pickup_latitude'], '.',  alpha = 0.4, markersize = 0.05)
plt.plot(df_train['dropoff_longitude'], df_train['dropoff_latitude'], '.',  alpha = 0.4, markersize = 0.05)
plt.show()
